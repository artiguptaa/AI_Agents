# %%
import ollama

response = ollama.chat(model="gemma3:4b",
                   messages=[{"role": "user", "content": "tell me friend function in c++?"}])

print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ollama
#       3 response = ollama.chat(model="gemma3:4b",
#       4                    messages=[{"role": "user", "content": "Hello, how are you?"}])
#       6 print(response)
#
# ModuleNotFoundError: No module named 'ollama'
